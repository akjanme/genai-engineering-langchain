# %%
corpus="""Hello Welcome,My name is anil sharma and I am learning NLP course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,My name is anil sharma and I am learning NLP course! to become expert in NLP.

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

words = word_tokenize(corpus)
sentences = sent_tokenize(corpus)

print("Words:", words)
print("Sentences:", sentences)
# Out:
# Words: ['Hello', 'Welcome', ',', 'My', 'name', 'is', 'anil', 'sharma', 'and', 'I', 'am', 'learning', 'NLP', 'course', '!', 'to', 'become', 'expert', 'in', 'NLP', '.']
# Sentences: ['Hello Welcome,My name is anil sharma and I am learning NLP course!', 'to become expert in NLP.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'anil',
#  'sharma',
#  'and',
#  'I',
#  'am',
#  'learning',
#  'NLP',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'anil',
#  'sharma',
#  'and',
#  'I',
#  'am',
#  'learning',
#  'NLP',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
